# %%
import numpy as np 
import pandas as pd
import json

# %%
meta = pd.read_csv('C:/python/workspace/movie/the-movies-dataset/movies_metadata_e.csv')
display(meta.head())
# Out:
#                                               genres     id original_language  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862                en
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844                en
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602                en
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357                en
# 4                     [{'id': 35, 'name': 'Comedy'}]  11862                en
#
#                 original_title                        title  Unnamed: 5  \
# 0                    Toy Story                    Toy Story         NaN
# 1                      Jumanji                      Jumanji         NaN
# 2             Grumpier Old Men             Grumpier Old Men         NaN
# 3            Waiting to Exhale            Waiting to Exhale         NaN
# 4  Father of the Bride Part II  Father of the Bride Part II         NaN
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# ...

# %%
meta = meta[['id','original_title','original_language','genres']]
meta = meta.rename(columns={'id':'movieId'})
meta = meta[meta['original_language']=='en']
display(meta.head())
# Out:
#   movieId               original_title original_language  \
# 0     862                    Toy Story                en
# 1    8844                      Jumanji                en
# 2   15602             Grumpier Old Men                en
# 3   31357            Waiting to Exhale                en
# 4   11862  Father of the Bride Part II                en
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]

# %%
ratings = pd.read_csv('C:/python/workspace/movie/the-movies-dataset/ratings_small.csv')
ratings = ratings[['userId', 'movieId', 'rating']]
display(ratings.head())
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %%
display(ratings.describe()) #count : 자료의 수 / mean : 평균값 / std : 표준편차
# Out:
#               userId        movieId         rating
# count  100004.000000  100004.000000  100004.000000
# mean      347.011310   12548.664363       3.543608
# std       195.163838   26369.198969       1.058064
# min         1.000000       1.000000       0.500000
# 25%       182.000000    1028.000000       3.000000
# 50%       367.000000    2406.500000       4.000000
# 75%       520.000000    5418.000000       4.000000
# max       671.000000  163949.000000       5.000000

# %%
meta.movieId = pd.to_numeric(meta.movieId, errors='coerce')
ratings.movieId = pd.to_numeric(ratings.movieId, errors='coerce')
